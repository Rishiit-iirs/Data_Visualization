# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('C:/Users/user1/Desktop/Data_Visualization/camera_dataset.csv')

# %%
src = ColumnDataSource(data)

# %%
data.head()
# Out:
#                     Model  Release date  Max resolution  Low resolution  \
# 0        Agfa ePhoto 1280          1997            1024             640
# 1        Agfa ePhoto 1680          1998            1280             640
# 2        Agfa ePhoto CL18          2000             640               0
# 3        Agfa ePhoto CL30          1999            1152             640
# 4  Agfa ePhoto CL30 Clik!          1999            1152             640
#
#    Effective pixels  Zoom wide (W)  Zoom tele (T)  Normal focus range  \
# 0                 0             38            114                  70
# 1                 1             38            114                  50
# 2                 0             45             45                   0
# 3                 0             35             35                   0
# 4                 0             43             43                  50
#
#    Macro focus range  Storage included  Weight (inc. batteries)  Dimensions  \
# ...

# %%
data.head()
# Out:
#                     Model  Release date  Max resolution  Low resolution  \
# 0        Agfa ePhoto 1280          1997            1024             640
# 1        Agfa ePhoto 1680          1998            1280             640
# 2        Agfa ePhoto CL18          2000             640               0
# 3        Agfa ePhoto CL30          1999            1152             640
# 4  Agfa ePhoto CL30 Clik!          1999            1152             640
#
#    Effective pixels  Zoom wide (W)  Zoom tele (T)  Normal focus range  \
# 0                 0             38            114                  70
# 1                 1             38            114                  50
# 2                 0             45             45                   0
# 3                 0             35             35                   0
# 4                 0             43             43                  50
#
#    Macro focus range  Storage included  Weight (inc. batteries)  Dimensions  \
# ...

# %%
data.describe()
# Out:
#        Release date  Max resolution  Low resolution  Effective pixels  \
# count   1038.000000     1038.000000     1038.000000       1038.000000
# mean    2003.590559     2474.672447     1773.936416          4.596339
# std        2.724755      759.513608      830.897955          2.844044
# min     1994.000000        0.000000        0.000000          0.000000
# 25%     2002.000000     2048.000000     1120.000000          3.000000
# 50%     2004.000000     2560.000000     2048.000000          4.000000
# 75%     2006.000000     3072.000000     2560.000000          7.000000
# max     2007.000000     5616.000000     4992.000000         21.000000
#
#        Zoom wide (W)  Zoom tele (T)  Normal focus range  Macro focus range  \
# count    1038.000000    1038.000000         1038.000000        1037.000000
# mean       32.963391     121.525048           44.145472           7.787850
# std        10.333149      93.455422           24.141959           8.100081
# ...

# %%
# Create a scatter plot of the data
plt.scatter(data['Price'], data['Max resolution'],alpha=0.5)

# Add axis labels and a title
plt.xlabel("Price")
plt.ylabel("Max resolution")
plt.title("Prices vs. Resolution")

# Display the plot
plt.show()

# %%
# Create a scatter plot of the data
plt.scatter(data['Price'], data['Max resolution'], alpha=0.5)

# Add axis labels and a title
plt.xlabel("Price")
plt.ylabel("Max resolution")
plt.title("Camera Prices vs. Megapixels")

# Set the x and y limits to zoom in on the high-end cameras
plt.xlim(1000, None)
plt.ylim(10, None)

# Display the plot
plt.show()

# %%
# Extract the columns of interest
max_res = data['Max resolution']
zoom_wide = data['Zoom wide (W)']

# Create a scatter plot
plt.scatter(max_res, zoom_wide)

# Set the axis labels and title
plt.xlabel('Max resolution')
plt.ylabel('Zoom wide (W)')
plt.title('Zooming and Focusing')

# Show the plot
plt.show()
